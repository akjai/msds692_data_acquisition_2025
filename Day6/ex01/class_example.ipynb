# %%
import requests

# %%
response = requests.get("http://127.0.0.1:8000/retrieve_and_store", {"url": "http://data.sfgov.org/resource/wg3w-h783"})
response.text
# Out:
# '{"message":"Successfully stored the extracted data"}'
